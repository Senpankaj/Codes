# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# My Jupyter Notebook on IBM Watson Studio

# %%
**Pankaj Sen**

Data Scientist

# %%
*I am interested in data science because I love discovering patterns and insights hidden in large datasets, and using this knowledge to make better decisions and drive positive change.*

# %%
## Popular Data Science Languages

Here are some of the most popular programming languages used for data science:

- Python
- R
- SQL
- MATLAB
- Julia
- Scala
- Java

Python and R are widely considered as the top languages for data science, but the others are also gaining popularity due to their unique strengths and applications.

# %%
## Popular Data Science Libraries

Here are some of the most popular libraries used in data science:

### Python Libraries
- NumPy: numerical computing library
- Pandas: data manipulation and analysis library
- Matplotlib: data visualization library
- SciPy: scientific computing library
- Scikit-learn: machine learning library
- TensorFlow: deep learning library

### R Libraries
- ggplot2: data visualization library
- dplyr: data manipulation library
- tidyr: data wrangling library
- caret: machine learning library
- shiny: web application framework for R

These are just a few of the many libraries available in Python and R that are commonly used in data science. Each library has its own strengths and applications, and can help data scientists perform various tasks more efficiently and effectively.

# %%
## Popular Data Science Tools

Here are some of the most popular tools used in data science:

| Tool Name | Description |
| --- | --- |
| Jupyter Notebook | web-based interactive computational environment for creating and sharing documents containing live code, equations, visualizations, and narrative text |
| Apache Hadoop | open-source software framework used for distributed storage and processing of large datasets |
| Apache Spark | open-source cluster computing system used for big data processing, machine learning, and graph processing |
| Tableau | business intelligence and data visualization tool used for exploring and analyzing data |
| SAS | statistical software suite used for data management, analytics, and reporting |
| Excel | spreadsheet program with data analysis capabilities |
| Power BI | business analytics service by Microsoft that provides interactive visualizations and business intelligence capabilities with an interface simple enough for end users to create their own reports and dashboards |

These tools offer a wide range of functionality for data scientists, from data storage and processing to visualization and reporting. Each tool has its own strengths and applications, and can be used to solve different types of problems in data science.

# %%
## Arithmetic Expressions

In mathematics, an arithmetic expression is a combination of numbers, variables, and mathematical operators that can be evaluated to produce a numerical result. 

Some common arithmetic operators include:

* Addition (+)
* Subtraction (-)
* Multiplication (*)
* Division (/)

For example, the expression "2 + 3" would evaluate to 5, while "10 / 5" would evaluate to 2. 

Arithmetic expressions are a fundamental concept in many fields, including mathematics, computer science, and engineering. In data science, they are often used in data analysis and machine learning algorithms to perform calculations and manipulate data.

# %%
# multiply and add numbers
x = 5
y = 10
z = x * y + 2
print(z)

# %%
# convert minutes to hours
minutes = 120
hours = minutes / 60
print(hours)

# %%
## Objectives

- Understand the basics of data science.
- Learn how to use Python for data analysis.
- Explore different types of data and how to work with them.
- Learn how to clean and preprocess data.
- Understand how to visualize and communicate insights from data.
- Gain experience working with real-world datasets and solving data-driven problems.

# %%
**Pankaj Sen**
